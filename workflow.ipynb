# %%
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # 🚀 Git-Flow Master Class: Calculator Project
#
# > **Instructor: 01 (Team Lead)** — Each member section includes a mini live graph showing the repo state after that member finishes.
#
# ---
#
# ## 👥 Team Assignments
#
# | Member | Round 1 Feature | Tag | Round 2 Feature | Tag |
# |--------|----------------|-----|----------------|-----|
# | **01** (Lead) | Addition | `{#{1}}` | Menu Structure | `{#{12}}` |
# | **02** | Subtraction | `{#{2}}` | Multiplication | `{#{5}}` |
# | **03** | Division | `{#{4}}` | Power | `{#{6}}` |
# | **04** | Sum (n) | `{#{3}}` | Logarithm | `{#{7}}` |
# | **05** | Modulo | `{#{8}}` | Square Root | `{#{10}}` |
# | **06** | Factorial | `{#{9}}` | Absolute Value | `{#{11}}` |
#
# ### ⚠️ Conflict Scenarios:
# - **Conflict 1 (Round 1)** — 02 & 03 both modify `calculator.py` → merge race → CONFLICT
# - **Conflict 2 (Round 1)** — 04 & 05 both modify `logger.py` → merge race → CONFLICT
# - **Hotfix** — 01 fixes `main.py` bug between Round 1 & Round 2
#
# ---

# %%
from mermaid import Mermaid

INIT = """
# %%{init: {
  'theme': 'base',
  'gitGraph': { 
    'rotateCommitLabel': true,
    'mainBranchOrder': 0   # optional: control main branch position
  },
  'themeVariables': {
    'git0': '#00ff00',     # main branch color (green example)
    'git1': '#ffffff',     # feature branch color (will be overridden by CSS for dash)
    'gitBranchLabel0': '#ffffff',
    'gitBranchLabel1': '#ffffff'
  },
  'themeCSS': `
    /* Target feature branch lines (the 2nd branch = git1) */
    .gitBranch1 path, 
    .git1 path {
      stroke: #ffffff !important;      /* white */
      stroke-width: 4px !important;    /* custom weight - change as needed */
      stroke-dasharray: 8, 4 !important; /* dashed: length, gap - adjust values */
      stroke-linecap: round !important;
    }
    
    /* Optional: make merge lines to main also visible */
    .gitMerge path {
      stroke: #00ff00 !important;
      stroke-width: 3px !important;
    }
  `
}}%%
"""

# %% [markdown]
# ---
# # 🔵 PHASE 1 — Project Initialization (Member 01)
#
# 01 creates the repo, initializes uv, sets up git-flow, and pushes the incomplete calculator stubs.
#
# ### 🛠️ Commands (01 only):
# ```bash
# mkdir calculator && cd calculator
# git init
# uv init && uv add mermaid-py ipykernel
# git flow init -d
# git add .
# git commit -m "feat: add base calculator stubs"
# git remote add origin <your-repo-url>
# git push -u origin main develop
# ```

# %%
# 📊 After Phase 1 — Repo state
Mermaid(INIT + """
gitGraph
    commit id: "P1-init: scaffold"
    branch develop
    checkout develop
    commit id: "P1-chore: uv init"
    commit id: "P1-feat: base stubs"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 275.1484375px;" viewBox="-117.1484375 -18 275.1484375 200.26048278808594" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermai
# ...

# %% [markdown]
# ---
# # 🟢 PHASE 2 — Round 1 Features
#
# All 6 members clone the repo and start their branches simultaneously. The graph evolves after each member finishes.
#
# > **⚠️ Note:** 02 & 03 both edit `calculator.py` → conflict when 03 merges. 04 & 05 both edit `logger.py` → conflict when 05 merges.
#
# ---
#
#
# > [!TIP]
# > 💡 **Tip:** Always run `git status` before `git add` and `git commit` to see your changes!

# %% [markdown]
# ## 👤 Member 01 — `{#{1}}`: `add()`
#
# ```bash
# git pull origin develop
# git flow feature start 01-add
# ```
# **Edit `calculator.py`** — find `{#{1}}`:
# ```python
# def add(a, b):
#     result = a + b
#     log_action("add", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement add() {#{1}}"
# git flow feature publish 01-add
# ```
#
# #### go to github -> tab pull request -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 01-add
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 01 finishes
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    checkout feature/01-add
    commit id: "R1-01: add()"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 373.078125px;" viewBox="-165.078125 -18 373.078125 269.4322052001953" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-sv
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 02 — `{#{2}}`: `subtract()`
#
# ```bash
# git pull origin develop
# git flow feature start 02-sub
# ```
# **Edit `calculator.py`** — find `{#{2}}`:
# ```python
# def subtract(a, b):
#     result = a - b
#     log_action("subtract", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement subtract() {#{2}}"
# ```
#
# ```bash
# git flow feature publish 02-sub
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 02-sub
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 02-sub
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 02 finishes
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    checkout feature/01-add
    commit id: "R1-01: add()"
    checkout feature/02-sub
    commit id: "R1-02: subtract()"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
    merge feature/02-sub id: "M-02 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 473.078125px;" viewBox="-165.078125 -18 473.078125 372.53387451171875" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-s
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 03 — `{#{4}}`: `divide()` ⚔️ CONFLICT WITH 02
#
# ```bash
# git pull origin develop
# git flow feature start 03-div
# ```
# **Edit `calculator.py`** — find `{#{4}}`:
# ```python
# def divide(a, b):
#     if b == 0:
#         raise ValueError("Cannot divide by zero")
#     result = a / b
#     log_action("divide", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement divide() {#{4}}"
# ```
#
# ```bash
# git flow feature publish 03-div
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 03-div
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```
#
#
# ```bash
# ```
#
#
# ```bash
# ```bash
# git flow feature finish 03-div
# ```
# ```bash
# git push origin develop
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 03 finishes (conflict resolved)
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
    merge feature/02-sub id: "M-02 ✅"
    merge feature/03-div id: "⚔️CF1 fixed"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 573.078125px;" viewBox="-165.078125 -18 573.078125 442.1065368652344" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-sv
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 04 — `{#{3}}`: `sum_n()` + logger edit ⚠️
#
# ```bash
# git pull origin develop
# git flow feature start 04-sum
# ```
# **Edit `calculator.py`** — find `{#{3}}`:
# ```python
# def sum_n(*args):
#     result = sum(args)
#     log_action("sum_n", result)
#     return result
# ```
# **Also edit `logger.py`** — change the log format:
# ```python
# def log_action(action_name, result):
#     timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open("calc_history.log", "a") as f:
#         f.write(f"[{timestamp}] ACTION={action_name} RESULT={result}\n")
# ```
# ```bash
# git add calculator.py logger.py
# git commit -m "feat: implement sum_n() and update log format {#{3}}"
# ```
#
# ```bash
# git flow feature publish 04-sum
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 04-sum
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```
#
# ```bash
# ```
#
#
# ```bash
# ```
#
#
#
#
# ```bash
# ```
#
#
# ```bash
# ```bash
# git flow feature finish 04-sum
# ```
# ```bash
# git push origin develop
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 04 finishes
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    branch feature/04-sum
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout feature/04-sum
    commit id: "R1-04: sum+log"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
    merge feature/02-sub id: "M-02 ✅"
    merge feature/03-div id: "⚔️CF1 fixed"
    merge feature/04-sum id: "M-04 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 676.609375px;" viewBox="-168.609375 -18 676.609375 549.6513061523438" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-sv
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 05 — `{#{8}}`: `modulo()` + logger edit ⚔️ CONFLICT WITH 04
#
# ```bash
# git pull origin develop
# git flow feature start 05-mod
# ```
# **Edit `calculator.py`** — find `{#{8}}`:
# ```python
# def modulo(a, b):
#     result = a % b
#     log_action("modulo", result)
#     return result
# ```
# **Also edit `logger.py`** — different format from 04:
# ```python
# def log_action(action_name, result):
#     timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open("calc_history.log", "a") as f:
#         f.write(f"[{timestamp}] ✅ {action_name}: {result}\n")
# ```
# ```bash
# git add calculator.py logger.py
# git commit -m "feat: implement modulo() and update log format {#{8}}"
# ```
#
# ```bash
# git flow feature publish 05-mod
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 05-mod
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 05-mod
# ```
# ```bash
# git push origin develop
# ```
# ```bash
# # Open logger.py — agree with 04 on ONE format, remove markers
# git add logger.py
# git commit -m "fix: resolve logger.py conflict"
# git push origin develop
# ```

# %%
# 📊 After 05 finishes (conflict resolved)
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    branch feature/04-sum
    branch feature/05-mod
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout feature/04-sum
    commit id: "R1-04: sum"
    checkout feature/05-mod
    commit id: "R1-05: mod+log"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
    merge feature/02-sub id: "M-02 ✅"
    merge feature/03-div id: "⚔️CF1 fixed"
    merge feature/04-sum id: "M-04 ✅"
    merge feature/05-mod id: "⚔️CF2 fixed"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 777.515625px;" viewBox="-169.515625 -18 777.515625 640.0414428710938" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-sv
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 06 — `{#{9}}`: `factorial()`
#
# ```bash
# git pull origin develop
# git flow feature start 06-factorial
# ```
# **Edit `calculator.py`** — find `{#{9}}`:
# ```python
# import math
#
# def factorial(n):
#     result = math.factorial(int(n))
#     log_action("factorial", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement factorial() {#{9}}"
# ```
#
# ```bash
# git flow feature publish 06-factorial
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 06-factorial
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 06-factorial
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 06 finishes — Round 1 COMPLETE ✅
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    branch feature/04-sum
    branch feature/05-mod
    branch feature/06-fact
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout feature/04-sum
    commit id: "R1-04: sum"
    checkout feature/05-mod
    commit id: "R1-05: mod"
    checkout feature/06-fact
    commit id: "R1-06: fact"
    checkout develop
    merge feature/01-add id: "M-01 ✅"
    merge feature/02-sub id: "M-02 ✅"
    merge feature/03-div id: "⚔️CF1"
    merge feature/04-sum id: "M-04 ✅"
    merge feature/05-mod id: "⚔️CF2"
    merge feature/06-fact id: "M-06 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 877.515625px;" viewBox="-169.515625 -18 877.515625 714.5718994140625" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-sv
# ...

# %%
# 📊 After Hotfix — Round 1 + Hotfix state
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    branch feature/04-sum
    branch feature/05-mod
    branch feature/06-fact
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout feature/04-sum
    commit id: "R1-04: sum"
    checkout feature/05-mod
    commit id: "R1-05: mod"
    checkout feature/06-fact
    commit id: "R1-06: fact"
    checkout develop
    merge feature/01-add id: "M-01"
    merge feature/02-sub id: "M-02"
    merge feature/03-div id: "CF1"
    merge feature/04-sum id: "M-04"
    merge feature/05-mod id: "CF2"
    merge feature/06-fact id: "M-06"
    checkout main
    merge develop tag: "v0.1"
    branch hotfix/fix-menu
    checkout hotfix/fix-menu
    commit id: "HF-fix: menu"
    checkout main
    merge hotfix/fix-menu tag: "v0.1.1"
    checkout develop
    merge hotfix/fix-menu
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 1077.515625px;" viewBox="-169.515625 -34.70000076293945 1077.515625 826.8908081054688" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#55
# ...

# %% [markdown]
# ---
# # 🟠 PHASE 4 — Round 2 Features
#
# Round 2 features.
#
# > **📣 Everyone:** `git pull origin develop` first to get the hotfix!
#
# ---
#
# | Member | Feature | Tag | Branch |
# |
# > [!TIP]
# > 💡 **Tip:** Always run `git status` before `git add` and `git commit` to see your changes!

# %% [markdown]
# ## 👤 Member 01 — `{#{12}}`: Complete `main()` Menu
#
# ```bash
# git pull origin develop
# git flow feature start 01-menu
# ```
# **Rewrite `main.py`** — complete the full menu:
# ```python
# import calculator
#
# def print_menu():
#     print("\n=== 🧮 Python Calculator ===")
#     print(" 1. Add         2. Subtract")
#     print(" 3. Multiply    4. Divide")
#     print(" 5. Power       6. Sum (n)")
#     print(" 7. Logarithm   8. Modulo")
#     print(" 9. Square Root 10. Factorial")
#     print("11. Absolute    0. Exit")
#
# def _ab():
#     return float(input('a: ')), float(input('b: '))
#
# def main():
#     while True:
#         print_menu()
#         choice = input("Select: ")
#         if choice == '0': print("Goodbye!"); break
#         try:
#             if   choice == '1':  a,b = _ab(); print(calculator.add(a,b))
#             elif choice == '2':  a,b = _ab(); print(calculator.subtract(a,b))
#             elif choice == '3':  a,b = _ab(); print(calculator.multiply(a,b))
#             elif choice == '4':  a,b = _ab(); print(calculator.divide(a,b))
#             elif choice == '5':  a,b = _ab(); print(calculator.power(a,b))
#             elif choice == '6':  nums=list(map(float,input('numbers: ').split())); print(calculator.sum_n(*nums))
#             elif choice == '7':  a=float(input('a: ')); print(calculator.logarithm(a))
#             elif choice == '8':  a,b = _ab(); print(calculator.modulo(a,b))
#             elif choice == '9':  a=float(input('a: ')); print(calculator.sq_root(a))
#             elif choice == '10': n=int(input('n: ')); print(calculator.factorial(n))
#             elif choice == '11': a=float(input('a: ')); print(calculator.absolute(a))
#             else: print('Invalid option')
#         except Exception as e:
#             print(f'Error: {e}')
#
# if __name__ == '__main__':
#     main()
# ```
# ```bash
# git add main.py
# git commit -m "feat: complete menu structure {#{12}}"
# git flow feature publish 01-menu
# ```
#
# #### go to github -> tab pull request -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 01-menu
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 01 finishes Round 2
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    checkout feature/01-menu
    commit id: "R2-01: menu()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 386.40625px;" viewBox="-178.40625 -18 386.40625 275.2082214355469" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-svg .
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 02 — `{#{5}}`: `multiply()`
#
# ```bash
# git pull origin develop
# git flow feature start 02-mul
# ```
# **Edit `calculator.py`** — find `{#{5}}`:
# ```python
# def multiply(a, b):
#     result = a * b
#     log_action("multiply", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement multiply() {#{5}}"
# ```
#
# ```bash
# git flow feature publish 02-mul
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 02-mul
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 02-mul
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 02 finishes Round 2
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    branch feature/02-mul
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: multiply()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
    merge feature/02-mul id: "FM-02 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 486.40625px;" viewBox="-178.40625 -18 486.40625 371.3743591308594" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-svg .
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 03 — `{#{6}}`: `power()`
#
# ```bash
# git pull origin develop
# git flow feature start 03-power
# ```
# **Edit `calculator.py`** — find `{#{6}}`:
# ```python
# import math
#
# def power(a, b):
#     result = math.pow(a, b)
#     log_action("power", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement power() {#{6}}"
# ```
#
# ```bash
# git flow feature publish 03-power
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 03-power
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 03-power
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 03 finishes Round 2
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    branch feature/02-mul
    branch feature/03-pow
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: mul"
    checkout feature/03-pow
    commit id: "R2-03: power()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
    merge feature/02-mul id: "FM-02 ✅"
    merge feature/03-pow id: "FM-03 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 586.40625px;" viewBox="-178.40625 -18 586.40625 456.75787353515625" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-svg 
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 04 — `{#{7}}`: `logarithm()`
#
# ```bash
# git pull origin develop
# git flow feature start 04-log
# ```
# **Edit `calculator.py`** — find `{#{7}}`:
# ```python
# import math
#
# def logarithm(a, base=10):
#     if a <= 0:
#         raise ValueError("Logarithm undefined for non-positive values")
#     result = math.log(a, base)
#     log_action("logarithm", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement logarithm() {#{7}}"
# ```
#
# ```bash
# git flow feature publish 04-log
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 04-log
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 04-log
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 04 finishes Round 2
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    branch feature/02-mul
    branch feature/03-pow
    branch feature/04-log
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: mul"
    checkout feature/03-pow
    commit id: "R2-03: pow"
    checkout feature/04-log
    commit id: "R2-04: log()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
    merge feature/02-mul id: "FM-02 ✅"
    merge feature/03-pow id: "FM-03 ✅"
    merge feature/04-log id: "FM-04 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 686.40625px;" viewBox="-178.40625 -18 686.40625 537.1239624023438" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-svg .
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 05 — `{#{10}}`: `sq_root()`
#
# ```bash
# git pull origin develop
# git flow feature start 05-sqrt
# ```
# **Edit `calculator.py`** — find `{#{10}}`:
# ```python
# import math
#
# def sq_root(a):
#     if a < 0:
#         raise ValueError("Cannot take square root of negative number")
#     result = math.sqrt(a)
#     log_action("sq_root", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement sq_root() {#{10}}"
# ```
#
# ```bash
# git flow feature publish 05-sqrt
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 05-sqrt
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 05-sqrt
# ```
# ```bash
# git push origin develop
# ```

# %%
# 📊 After 05 finishes Round 2
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    branch feature/02-mul
    branch feature/03-pow
    branch feature/04-log
    branch feature/05-sqrt
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: mul"
    checkout feature/03-pow
    commit id: "R2-03: pow"
    checkout feature/04-log
    commit id: "R2-04: log"
    checkout feature/05-sqrt
    commit id: "R2-05: sqrt()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
    merge feature/02-mul id: "FM-02 ✅"
    merge feature/03-pow id: "FM-03 ✅"
    merge feature/04-log id: "FM-04 ✅"
    merge feature/05-sqrt id: "FM-05 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 786.40625px;" viewBox="-178.40625 -18 786.40625 629.42138671875" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:hsl(220.5882352941, 100%, 98.3333333333%);}#mermaid-svg .error-text{fill:rgb(8.
# ...

# %% [markdown]
# ---
#
# ## 👤 Member 06 — `{#{11}}`: `absolute()`
#
# ```bash
# git pull origin develop
# git flow feature start 06-abs
# ```
# **Edit `calculator.py`** — find `{#{11}}`:
# ```python
# def absolute(a):
#     result = abs(a)
#     log_action("absolute", result)
#     return result
# ```
# ```bash
# git add calculator.py
# git commit -m "feat: implement absolute() {#{11}}"
# ```
#
# ```bash
# git flow feature publish 06-abs
# ```
#
# #### go to github -> tab pull reuqest -> wait for approval
#
# ```bash
# git switch develop
# git pull origin develop
# ```
#
# #### after approve
#
# ```bash
# git flow feature finish 06-abs
# ```
#
# **Note:** You are now on the `develop` branch. If there are any conflicts, solve them now before pushing.
#
# ```bash
# git push origin develop
# ```
# ```bash
# git flow feature finish 06-abs
# ```
# ```bash
# git push origin develop
# ```
# ```bash
# git pull origin develop
# uv run python main.py
# ```

# %%
# 📊 After 06 finishes Round 2 — ALL features complete ✅
Mermaid(INIT + """
gitGraph
    commit id: "develop-w-hotfix"
    branch develop
    checkout develop
    commit id: "HF-merged"
    branch feature/01-menu
    branch feature/02-mul
    branch feature/03-pow
    branch feature/04-log
    branch feature/05-sqrt
    branch feature/06-abs
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: mul"
    checkout feature/03-pow
    commit id: "R2-03: pow"
    checkout feature/04-log
    commit id: "R2-04: log"
    checkout feature/05-sqrt
    commit id: "R2-05: sqrt"
    checkout feature/06-abs
    commit id: "R2-06: abs()"
    checkout develop
    merge feature/01-menu id: "FM-01 ✅"
    merge feature/02-mul id: "FM-02 ✅"
    merge feature/03-pow id: "FM-03 ✅"
    merge feature/04-log id: "FM-04 ✅"
    merge feature/05-sqrt id: "FM-05 ✅"
    merge feature/06-abs id: "FM-06 ✅"
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 886.40625px;" viewBox="-178.40625 -18 886.40625 719.0420532226562" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:hsl(220.5882352941, 100%, 98.3333333333%);}#mermaid-svg .error-text{fill:rgb(
# ...

# %% [markdown]
# ---
# # 🎁 PHASE 5 — Release v1.0.0 (Member 01)
#
# ```bash
# git flow release start 1.0.0
# # Edit pyproject.toml: version = "1.0.0"
# git add pyproject.toml
# git commit -m "chore: bump version to 1.0.0"
# git flow release finish 1.0.0
# git push origin main develop --tags
# ```
#
# 🎉 **Project complete! All 12 features shipped as v1.0.0!**

# %%
# 📊 After Release — Phase 5
Mermaid(INIT + """
gitGraph
    commit id: "all-features-merged"
    branch develop
    checkout develop
    commit id: "FM-06-done"
    branch release/1.0.0
    checkout release/1.0.0
    commit id: "REL-bump v1.0.0"
    checkout main
    merge release/1.0.0 tag: "v1.0.0"
    checkout develop
    merge release/1.0.0
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 411.609375px;" viewBox="-153.609375 -34.70000076293945 411.609375 301.4703063964844" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:hsl(220.5882352941, 100%, 98.3333333333%);}#mermaid-svg .er
# ...

# %% [markdown]
# ---
# # 🗺️ FULL LIFECYCLE — Complete History (Phase 1 → Phase 5)

# %%
# 📊 FULL LIFECYCLE: Init → Round 1 → Hotfix → Round 2 → Release
Mermaid(INIT + """
gitGraph
    commit id: "P1-init"
    branch develop
    checkout develop
    commit id: "P1-stubs"
    branch feature/01-add
    branch feature/02-sub
    branch feature/03-div
    branch feature/04-sum
    branch feature/05-mod
    branch feature/06-fact
    checkout feature/01-add
    commit id: "R1-01: add"
    checkout feature/02-sub
    commit id: "R1-02: sub"
    checkout feature/03-div
    commit id: "R1-03: div"
    checkout feature/04-sum
    commit id: "R1-04: sum"
    checkout feature/05-mod
    commit id: "R1-05: mod"
    checkout feature/06-fact
    commit id: "R1-06: fact"
    checkout develop
    merge feature/01-add id: "M-01"
    merge feature/02-sub id: "M-02"
    merge feature/03-div id: "CF1"
    merge feature/04-sum id: "M-04"
    merge feature/05-mod id: "CF2"
    merge feature/06-fact id: "M-06"
    checkout main
    merge develop tag: "v0.1"
    branch hotfix/fix-menu
    checkout hotfix/fix-menu
    commit id: "HF-fix"
    checkout main
    merge hotfix/fix-menu tag: "v0.1.1"
    checkout develop
    merge hotfix/fix-menu
    branch feature/01-menu
    branch feature/02-mul
    branch feature/03-pow
    branch feature/04-log
    branch feature/05-sqrt
    branch feature/06-abs
    checkout feature/01-menu
    commit id: "R2-01: menu"
    checkout feature/02-mul
    commit id: "R2-02: mul"
    checkout feature/03-pow
    commit id: "R2-03: pow"
    checkout feature/04-log
    commit id: "R2-04: log"
    checkout feature/05-sqrt
    commit id: "R2-05: sqrt"
    checkout feature/06-abs
    commit id: "R2-06: abs"
    checkout develop
    merge feature/01-menu id: "FM-01"
    merge feature/02-mul id: "FM-02"
    merge feature/03-pow id: "FM-03"
    merge feature/04-log id: "FM-04"
    merge feature/05-sqrt id: "FM-05"
    merge feature/06-abs id: "FM-06"
    branch release/1.0.0
    checkout release/1.0.0
    commit id: "REL-bump v1.0.0"
    checkout main
    merge release/1.0.0 tag: "v1.0.0"
    checkout develop
    merge release/1.0.0
""")
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" style="max-width: 1836.40625px;" viewBox="-178.40625 -34.70000076293945 1836.40625 1471.47021484375" role="graphics-document document" aria-roledescription="gitGraph" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:hsl(220.5882352941, 100%, 98.3333333333%);}#mermaid-svg .erro
# ...
